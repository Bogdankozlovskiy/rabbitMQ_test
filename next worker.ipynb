# %%
#worker
import pika
import time

credentials = pika.PlainCredentials('rabbitmq', 'rabbitmq')# login password
parameters = pika.ConnectionParameters('rabbitmq', 5672, '/', credentials)
connection = pika.BlockingConnection(parameters)
channel = connection.channel()

channel.queue_declare(queue='task_queue', durable=True)
print(' [*] Waiting for messages. To exit press CTRL+C')


def callback(ch, method, properties, body):
    print(" [x] Received %r" % body)
    time.sleep(body.count(b'.'))
    print(" [x] Done")
    ch.basic_ack(delivery_tag=method.delivery_tag)

while True:
    channel.basic_qos(prefetch_count=1)
    channel.basic_consume(queue='task_queue', on_message_callback=callback)

    channel.start_consuming()
# Out:
#  [*] Waiting for messages. To exit press CTRL+C
#  [x] Received b'Hello..30'
#  [x] Done
#  [x] Received b'Hello..32'
#  [x] Done
#  [x] Received b'Hello..34'
#  [x] Done
#  [x] Received b'Hello..36'
#  [x] Done
#  [x] Received b'Hello..38'
#  [x] Done
#  [x] Received b'Hello..40'
#  [x] Done
#  [x] Received b'Hello..42'
#  [x] Done
#  [x] Received b'Hello..44'
#  [x] Done
#  [x] Received b'Hello..46'
#  [x] Done
#  [x] Received b'Hello..48'
#  [x] Done
#  [x] Received b'Hello..50'
#  [x] Done
#  [x] Received b'Hello..52'
#  [x] Done
#  [x] Received b'Hello..54'
#  [x] Done
#  [x] Received b'Hello..56'
#  [x] Done
#  [x] Received b'Hello..58'
#  [x] Done
#  [x] Received b'Hello..60'
#  [x] Done
#  [x] Received b'Hello..62'
#  [x] Done
#  [x] Received b'Hello..64'
#  [x] Done
#  [x] Received b'Hello..66'
#  [x] Done
#  [x] Received b'Hello..68'
#  [x] Done
#  [x] Received b'Hello..70'
#  [x] Done
#  [x] Received b'Hello..72'
#  [x] Done
#  [x] Received b'Hello..74'
#  [x] Done
#  [x] Received b'Hello..76'
#  [x] Done
#  [x] Received b'Hello..78'
#  [x] Done
#  [x] Received b'Hello..80'
#  [x] Done
#  [x] Received b'Hello..82'
#  [x] Done
#  [x] Received b'Hello..84'
#  [x] Done
#  [x] Received b'Hello..86'
#  [x] Done
#  [x] Received b'Hello..88'
#  [x] Done
#  [x] Received b'Hello..90'
#  [x] Done
#  [x] Received b'Hello..92'
#  [x] Done
#  [x] Received b'Hello..94'
#  [x] Done
#  [x] Received b'Hello..96'
#  [x] Done
#  [x] Received b'Hello..98'
#  [x] Done
#  [x] Received b'Hello..100'
#  [x] Done

# %% [markdown]
# ***

# %%
import pika

credentials = pika.PlainCredentials('rabbitmq', 'rabbitmq')# login password
parameters = pika.ConnectionParameters('rabbitmq', 5672, '/', credentials)
connection = pika.BlockingConnection(parameters)
channel = connection.channel()

channel.exchange_declare(exchange='logs', exchange_type='fanout')

result = channel.queue_declare(queue='', exclusive=True)
queue_name = result.method.queue

channel.queue_bind(exchange='logs', queue=queue_name)

print(' [*] Waiting for logs. To exit press CTRL+C')

def callback(ch, method, properties, body):
    print(" [x] %r" % body)

while True:
    channel.basic_consume(queue=queue_name, on_message_callback=callback, auto_ack=True)
    channel.start_consuming()
# Out:
#  [*] Waiting for logs. To exit press CTRL+C
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World!'
#  [x] b'info: Hello World! 0'
#  [x] b'info: Hello World! 1'
#  [x] b'info: Hello World! 2'
#  [x] b'info: Hello World! 3'
#  [x] b'info: Hello World! 4'
#  [x] b'info: Hello World! 5'
#  [x] b'info: Hello World! 6'
#  [x] b'info: Hello World! 7'
#  [x] b'info: Hello World! 8'
#  [x] b'info: Hello World! 9'
#  [x] b'info: Hello World! 10'
#  [x] b'info: Hello World! 11'
#  [x] b'info: Hello World! 12'
#  [x] b'info: Hello World! 13'
#  [x] b'info: Hello World! 14'
#  [x] b'info: Hello World! 15'
#  [x] b'info: Hello World! 16'
#  [x] b'info: Hello World! 17'
#  [x] b'info: Hello World! 18'
#  [x] b'info: Hello World! 19'
#  [x] b'info: Hello World! 20'
#  [x] b'info: Hello World! 21'
#  [x] b'info: Hello World! 22'
#  [x] b'info: Hello World! 23'
#  [x] b'info: Hello World! 24'
#  [x] b'info: Hello World! 25'
#  [x] b'info: Hello World! 26'
#  [x] b'info: Hello World! 27'
#  [x] b'info: Hello World! 28'
#  [x] b'info: Hello World! 29'
#  [x] b'info: Hello World! 30'
#  [x] b'info: Hello World! 31'
#  [x] b'info: Hello World! 32'
#  [x] b'info: Hello World! 33'
#  [x] b'info: Hello World! 34'
#  [x] b'info: Hello World! 35'
#  [x] b'info: Hello World! 36'
#  [x] b'info: Hello World! 37'
#  [x] b'info: Hello World! 38'
#  [x] b'info: Hello World! 39'
#  [x] b'info: Hello World! 40'
#  [x] b'info: Hello World! 41'
#  [x] b'info: Hello World! 42'
#  [x] b'info: Hello World! 43'
#  [x] b'info: Hello World! 44'
#  [x] b'info: Hello World! 45'
#  [x] b'info: Hello World! 46'
#  [x] b'info: Hello World! 47'
#  [x] b'info: Hello World! 48'
#  [x] b'info: Hello World! 49'
#  [x] b'info: Hello World! 50'
#  [x] b'info: Hello World! 51'
#  [x] b'info: Hello World! 52'
#  [x] b'info: Hello World! 53'
#  [x] b'info: Hello World! 54'
#  [x] b'info: Hello World! 55'
#  [x] b'info: Hello World! 56'
#  [x] b'info: Hello World! 57'
#  [x] b'info: Hello World! 58'
#  [x] b'info: Hello World! 59'
#  [x] b'info: Hello World! 60'
#  [x] b'info: Hello World! 61'
#  [x] b'info: Hello World! 62'
#  [x] b'info: Hello World! 63'
#  [x] b'info: Hello World! 64'
#  [x] b'info: Hello World! 65'
#  [x] b'info: Hello World! 66'
#  [x] b'info: Hello World! 67'
#  [x] b'info: Hello World! 68'
#  [x] b'info: Hello World! 69'
#  [x] b'info: Hello World! 70'
#  [x] b'info: Hello World! 71'
#  [x] b'info: Hello World! 72'
#  [x] b'info: Hello World! 73'
#  [x] b'info: Hello World! 74'
#  [x] b'info: Hello World! 75'
#  [x] b'info: Hello World! 76'
#  [x] b'info: Hello World! 77'
#  [x] b'info: Hello World! 78'
#  [x] b'info: Hello World! 79'
#  [x] b'info: Hello World! 80'
#  [x] b'info: Hello World! 81'
#  [x] b'info: Hello World! 82'
#  [x] b'info: Hello World! 83'
#  [x] b'info: Hello World! 84'
#  [x] b'info: Hello World! 85'
#  [x] b'info: Hello World! 86'
#  [x] b'info: Hello World! 87'
#  [x] b'info: Hello World! 88'
#  [x] b'info: Hello World! 89'
#  [x] b'info: Hello World! 90'
#  [x] b'info: Hello World! 91'
#  [x] b'info: Hello World! 92'
#  [x] b'info: Hello World! 93'
#  [x] b'info: Hello World! 94'
#  [x] b'info: Hello World! 95'
#  [x] b'info: Hello World! 96'
#  [x] b'info: Hello World! 97'
#  [x] b'info: Hello World! 98'
#  [x] b'info: Hello World! 99'
#  [x] b'info: Hello World! 100'

# %% [markdown]
# ***

# %%
import pika
import sys

credentials = pika.PlainCredentials('rabbitmq', 'rabbitmq')# login password
parameters = pika.ConnectionParameters('rabbitmq', 5672, '/', credentials)
connection = pika.BlockingConnection(parameters)
channel = connection.channel()

channel.exchange_declare(exchange='direct_logs', exchange_type='direct')

result = channel.queue_declare(queue='', exclusive=True)
queue_name = result.method.queue

severity = 'error'

channel.queue_bind(exchange='direct_logs', queue=queue_name, routing_key=severity)

print(' [*] Waiting for logs. To exit press CTRL+C')


def callback(ch, method, properties, body):
    print(" [x] %10r:%r" % (method.routing_key, body))

while True:
    channel.basic_consume(queue=queue_name, on_message_callback=callback, auto_ack=True)
    channel.start_consuming()
# Out:
#  [*] Waiting for logs. To exit press CTRL+C
#  [x]    'error':b'Hello World! 2'
#  [x]    'error':b'Hello World! 5'
#  [x]    'error':b'Hello World! 8'
#  [x]    'error':b'Hello World! 11'
#  [x]    'error':b'Hello World! 14'
#  [x]    'error':b'Hello World! 17'
#  [x]    'error':b'Hello World! 20'
#  [x]    'error':b'Hello World! 23'
#  [x]    'error':b'Hello World! 26'
#  [x]    'error':b'Hello World! 29'
#  [x]    'error':b'Hello World! 32'
#  [x]    'error':b'Hello World! 35'
#  [x]    'error':b'Hello World! 38'
#  [x]    'error':b'Hello World! 41'
#  [x]    'error':b'Hello World! 44'
#  [x]    'error':b'Hello World! 47'
#  [x]    'error':b'Hello World! 50'
#  [x]    'error':b'Hello World! 53'
#  [x]    'error':b'Hello World! 56'
#  [x]    'error':b'Hello World! 59'
#  [x]    'error':b'Hello World! 62'
#  [x]    'error':b'Hello World! 65'
#  [x]    'error':b'Hello World! 68'
#  [x]    'error':b'Hello World! 71'
#  [x]    'error':b'Hello World! 74'
#  [x]    'error':b'Hello World! 77'
#  [x]    'error':b'Hello World! 80'
#  [x]    'error':b'Hello World! 83'
#  [x]    'error':b'Hello World! 86'
#  [x]    'error':b'Hello World! 89'
#  [x]    'error':b'Hello World! 92'
#  [x]    'error':b'Hello World! 95'
#  [x]    'error':b'Hello World! 98'
#  [x]    'error':b'Hello World! 101'

# %% [markdown]
# ***

# %%
import pika
import sys

credentials = pika.PlainCredentials('rabbitmq', 'rabbitmq')# login password
parameters = pika.ConnectionParameters('rabbitmq', 5672, '/', credentials)
connection = pika.BlockingConnection(parameters)
channel = connection.channel()

channel.exchange_declare(exchange='topic_logs', exchange_type='topic')

result = channel.queue_declare('', exclusive=True)
queue_name = result.method.queue

binding_keys = ['*.info']


for binding_key in binding_keys:
    channel.queue_bind(exchange='topic_logs', queue=queue_name, routing_key=binding_key)

print(' [*] Waiting for logs. To exit press CTRL+C')


def callback(ch, method, properties, body):
    print(" [x] %r:%r" % (method.routing_key, body))

while True:
    channel.basic_consume(queue=queue_name, on_message_callback=callback, auto_ack=True)
    channel.start_consuming()
# Out:
#  [*] Waiting for logs. To exit press CTRL+C
#  [x] 'anonymous.info':b'Hello World!0'
#  [x] 'anonymous.info':b'Hello World!1'
#  [x] 'anonymous.info':b'Hello World!2'
#  [x] 'anonymous.info':b'Hello World!3'
#  [x] 'anonymous.info':b'Hello World!4'
#  [x] 'anonymous.info':b'Hello World!5'
#  [x] 'anonymous.info':b'Hello World!6'
#  [x] 'anonymous.info':b'Hello World!7'
#  [x] 'anonymous.info':b'Hello World!8'
#  [x] 'anonymous.info':b'Hello World!9'
#  [x] 'anonymous.info':b'Hello World!10'
#  [x] 'anonymous.info':b'Hello World!11'
#  [x] 'anonymous.info':b'Hello World!12'
#  [x] 'anonymous.info':b'Hello World!13'
#  [x] 'anonymous.info':b'Hello World!14'
#  [x] 'anonymous.info':b'Hello World!15'
#  [x] 'anonymous.info':b'Hello World!16'
#  [x] 'anonymous.info':b'Hello World!17'
#  [x] 'anonymous.info':b'Hello World!18'
#  [x] 'anonymous.info':b'Hello World!19'
#  [x] 'anonymous.info':b'Hello World!20'
#  [x] 'anonymous.info':b'Hello World!21'
#  [x] 'anonymous.info':b'Hello World!22'
#  [x] 'anonymous.info':b'Hello World!23'
#  [x] 'anonymous.info':b'Hello World!24'
#  [x] 'anonymous.info':b'Hello World!25'
#  [x] 'anonymous.info':b'Hello World!26'
#  [x] 'anonymous.info':b'Hello World!27'
#  [x] 'anonymous.info':b'Hello World!28'
#  [x] 'anonymous.info':b'Hello World!29'
#  [x] 'anonymous.info':b'Hello World!30'
#  [x] 'anonymous.info':b'Hello World!31'
#  [x] 'anonymous.info':b'Hello World!32'
#  [x] 'anonymous.info':b'Hello World!33'
#  [x] 'anonymous.info':b'Hello World!34'
#  [x] 'anonymous.info':b'Hello World!35'
#  [x] 'anonymous.info':b'Hello World!36'
#  [x] 'anonymous.info':b'Hello World!37'
#  [x] 'anonymous.info':b'Hello World!38'
#  [x] 'anonymous.info':b'Hello World!39'
#  [x] 'anonymous.info':b'Hello World!40'
#  [x] 'anonymous.info':b'Hello World!41'
#  [x] 'anonymous.info':b'Hello World!42'
#  [x] 'anonymous.info':b'Hello World!43'
#  [x] 'anonymous.info':b'Hello World!44'
#  [x] 'anonymous.info':b'Hello World!45'
#  [x] 'anonymous.info':b'Hello World!46'
#  [x] 'anonymous.info':b'Hello World!47'
#  [x] 'anonymous.info':b'Hello World!48'
#  [x] 'anonymous.info':b'Hello World!49'
#  [x] 'anonymous.info':b'Hello World!50'
#  [x] 'anonymous.info':b'Hello World!51'
#  [x] 'anonymous.info':b'Hello World!52'
#  [x] 'anonymous.info':b'Hello World!53'
#  [x] 'anonymous.info':b'Hello World!54'
#  [x] 'anonymous.info':b'Hello World!55'
#  [x] 'anonymous.info':b'Hello World!56'
#  [x] 'anonymous.info':b'Hello World!57'
#  [x] 'anonymous.info':b'Hello World!58'
#  [x] 'anonymous.info':b'Hello World!59'
#  [x] 'anonymous.info':b'Hello World!60'
#  [x] 'anonymous.info':b'Hello World!61'
#  [x] 'anonymous.info':b'Hello World!62'
#  [x] 'anonymous.info':b'Hello World!63'
#  [x] 'anonymous.info':b'Hello World!64'
#  [x] 'anonymous.info':b'Hello World!65'
#  [x] 'anonymous.info':b'Hello World!66'
#  [x] 'anonymous.info':b'Hello World!67'
#  [x] 'anonymous.info':b'Hello World!68'
#  [x] 'anonymous.info':b'Hello World!69'
#  [x] 'anonymous.info':b'Hello World!70'
#  [x] 'anonymous.info':b'Hello World!71'
#  [x] 'anonymous.info':b'Hello World!72'
#  [x] 'anonymous.info':b'Hello World!73'
#  [x] 'anonymous.info':b'Hello World!74'
#  [x] 'anonymous.info':b'Hello World!75'
#  [x] 'anonymous.info':b'Hello World!76'
#  [x] 'anonymous.info':b'Hello World!77'
#  [x] 'anonymous.info':b'Hello World!78'
#  [x] 'anonymous.info':b'Hello World!79'
#  [x] 'anonymous.info':b'Hello World!80'
#  [x] 'anonymous.info':b'Hello World!81'
#  [x] 'anonymous.info':b'Hello World!82'
#  [x] 'anonymous.info':b'Hello World!83'
#  [x] 'anonymous.info':b'Hello World!84'
#  [x] 'anonymous.info':b'Hello World!85'
#  [x] 'anonymous.info':b'Hello World!86'
#  [x] 'anonymous.info':b'Hello World!87'
#  [x] 'anonymous.info':b'Hello World!88'
#  [x] 'anonymous.info':b'Hello World!89'
#  [x] 'anonymous.info':b'Hello World!90'
#  [x] 'anonymous.info':b'Hello World!91'
#  [x] 'anonymous.info':b'Hello World!92'
#  [x] 'anonymous.info':b'Hello World!93'
#  [x] 'anonymous.info':b'Hello World!94'
#  [x] 'anonymous.info':b'Hello World!95'
#  [x] 'anonymous.info':b'Hello World!96'
#  [x] 'anonymous.info':b'Hello World!97'
#  [x] 'anonymous.info':b'Hello World!98'
#  [x] 'anonymous.info':b'Hello World!99'

# %% [markdown]
# ***
